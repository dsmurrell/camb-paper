# %%
 
import numpy as np
import os,sys
import gzip
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
import rdkit.rdBase
from rdkit.Chem.MACCSkeys import GenMACCSKeys
from rdkit import DataStructs
from rdkit.DataStructs import BitVectToText
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit import DataStructs
from rdkit.Chem import MCS as MCS
from rdkit.Chem import Descriptors as Descriptors
from rdkit.ML.Descriptors import MoleculeDescriptors
import pandas as pd 
from rdkit.Chem import PandasTools as PandasTools
from rdkit.Chem import Descriptors as Descriptors
import pylab as plt
from sklearn import tree, grid_search,cross_validation
from sklearn.cross_validation import StratifiedKFold
from sklearn.cross_validation import KFold
from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score
from sklearn import preprocessing
from sklearn.grid_search import GridSearchCV

# %%
#validation_functions
# The definition of these validation metrics can be found here:
# Tropsha, A.; Golbraikh, A. Predictive Quantitative Structure-Activity Relationships Modeling: 
#Development and Validation of QSAR Models. In: Handbook of Chemoinformatics Algorithms 
#(Faulon, J.-L.; Bender, A., Eds.), Chapter 7, pp. 213-233, Chapman & Hall / CRC, London, UK, 2010.

def slope(pred,true):
    return ( np.sum(true*pred) / np.sum(pred*pred) )

def Rsquared0(pred,true):
      true_mean = true.mean()
      yr0 = pred * slope(pred,true)
      first_term = (true - yr0)**2 #(true - yr0)
      second_term = (true-true_mean)**2 #(true-true_mean)
      return (1 - ( np.sum(first_term) / np.sum(second_term) ) )
  
def Rsquared(pred,true):
    true_mean = true.mean()
    pred_mean = pred.mean()
    first_term = np.sum( (true-true_mean) * (pred - pred_mean) )
    second_term = np.sqrt( np.sum( (true-true_mean)**2) * np.sum( (true-pred_mean)**2) )
    div = first_term / second_term
    return div

def Qsquared(pred,true):
    true_mean = true.mean()
    first_term = (np.abs(pred-true))**2
    second_term = (np.abs(true-true_mean))**2
    ret = 1 - (np.sum(first_term) / np.sum(second_term))
    return ret

def RMSE(pred,true):
    rmse = np.sqrt(mean_squared_error(true,pred))
    return rmse


class ValidationMetrics:
    def __init__(self, pred,true):
        self.RMSE = RMSE(pred,true)
        self.Qsquared = Qsquared(pred,true)
        self.Rsquared = Rsquared(pred,true)
        self.Rsquared0 = Rsquared0(pred,true)
        self.slope = slope(pred,true)

# %%
frame1 = pd.read_table('1.txt')
frame2 = pd.read_table('2.txt')
frame3 = pd.read_table('3.txt')
frame4 = pd.read_table('4.txt')
frame5 = pd.read_table('5.txt')

print frame1
print frame2
print frame3
print frame4
print frame5
# Out:
#     X   Y
# 0   1   1
# 1   2   2
# 2   3   3
# 3   4   4
# 4   5   5
# 5   6   6
# 6   7   7
# 7   8   8
# 8   9   9
# 9  10  10
#     X   Y
# 0   1  10
# 1   2   9
# 2   3   8
# 3   4   7
# 4   5   6
# 5   6   5
# 6   7   4
# 7   8   3
# 8   9   2
# 9  10   1
#     X  Y
# 0   6  7
# 1   6  6
# 2   8  7
# 3   7  8
# 4   5  6
# 5   6  5
# 6   7  7
# 7   8  9
# 8   9  8
# 9  10  9
#     X          Y
# 0   6   6.000000
# 1   6   5.831275
# 2   8   7.074670
# 3   7   6.218795
# 4   5   5.622406
# 5   6   6.525714
# 6   7   7.851489
# 7   8   8.331665
# 8   9   8.254843
# 9  10  10.998296
#     X     Y
# 0   6   6.5
# 1   6   5.5
# 2   8   7.5
# 3   7   6.5
# 4   5   5.0
# 5   6   5.5
# 6   7   7.0
# 7   8   7.5
# 8   9   8.5
# 9  10  10.5

# %%
#external validation metrics
print '1'
extvmetrics = ValidationMetrics(frame1.X , frame1.Y)
print "RMSE: ", extvmetrics.RMSE
print "Q_squared: ", extvmetrics.Qsquared
print "R_squared: ", extvmetrics.Rsquared
print "R_squared_0: ", extvmetrics.Rsquared0
print "Slope: ", extvmetrics.slope
print "Scikit_Explained_variance: " , explained_variance_score(frame1.X , frame1.Y)
print "Scikit_R2_score: " , r2_score(frame1.X , frame1.Y)
print "Scikit_MSE: " , mean_squared_error(frame1.X , frame1.Y)

print ''
print '2'
extvmetrics = ValidationMetrics(frame2.X , frame2.Y)
print "RMSE: ", extvmetrics.RMSE
print "Q_squared: ", extvmetrics.Qsquared
print "R_squared: ", extvmetrics.Rsquared
print "R_squared_0: ", extvmetrics.Rsquared0
print "Slope: ", extvmetrics.slope
print "Scikit_Explained_variance: " , explained_variance_score(frame2.X , frame2.Y)
print "Scikit_R2_score: " , r2_score(frame2.X , frame2.Y)
print "Scikit_MSE: " , mean_squared_error(frame2.X , frame2.Y)

print ''
print '3'
extvmetrics = ValidationMetrics(frame3.X , frame3.Y)
print "RMSE: ", extvmetrics.RMSE
print "Q_squared: ", extvmetrics.Qsquared
print "R_squared: ", extvmetrics.Rsquared
print "R_squared_0: ", extvmetrics.Rsquared0
print "Slope: ", extvmetrics.slope
print "Scikit_Explained_variance: " , explained_variance_score(frame3.X , frame3.Y)
print "Scikit_R2_score: " , r2_score(frame3.X , frame3.Y)
print "Scikit_MSE: " , mean_squared_error(frame3.X , frame3.Y)

print ''
print '4'
extvmetrics = ValidationMetrics(frame4.X , frame4.Y)
print "RMSE: ", extvmetrics.RMSE
print "Q_squared: ", extvmetrics.Qsquared
print "R_squared: ", extvmetrics.Rsquared
print "R_squared_0: ", extvmetrics.Rsquared0
print "Slope: ", extvmetrics.slope
print "Scikit_Explained_variance: " , explained_variance_score(frame4.X , frame4.Y)
print "Scikit_R2_score: " , r2_score(frame4.X , frame4.Y)
print "Scikit_MSE: " , mean_squared_error(frame4.X , frame4.Y)

print ''
print '5'
extvmetrics = ValidationMetrics(frame5.X , frame5.Y)
print "RMSE: ", extvmetrics.RMSE
print "Q_squared: ", extvmetrics.Qsquared
print "R_squared: ", extvmetrics.Rsquared
print "R_squared_0: ", extvmetrics.Rsquared0
print "Slope: ", extvmetrics.slope
print "Scikit_Explained_variance: " , explained_variance_score(frame5.X , frame5.Y)
print "Scikit_R2_score: " , r2_score(frame5.X , frame5.Y)
print "Scikit_MSE: " , mean_squared_error(frame5.X , frame5.Y)
# Out:
# 1
# RMSE:  0.0
# Q_squared:  1.0
# R_squared:  1.0
# R_squared_0:  1.0
# Slope:  1
# Scikit_Explained_variance:  1.0
# Scikit_R2_score:  1.0
# Scikit_MSE:  0.0
#
# 2
# RMSE:  5.74456264654
# Q_squared:  -3.0
# R_squared:  -1.0
# R_squared_0:  -3.66666666667
# Slope:  0
# Scikit_Explained_variance:  -3.0
# Scikit_R2_score:  -3.0
# Scikit_MSE:  33.0
#
# 3
# RMSE:  0.894427191
# Q_squared:  0.487179487179
# R_squared:  0.935897435897
# R_squared_0:  -33.2307692308
# Slope:  0
# Scikit_Explained_variance:  0.62962962963
# Scikit_R2_score:  0.62962962963
# Scikit_MSE:  0.8
#
# 4
# RMSE:  0.67421346654
# Q_squared:  0.813931423725
# R_squared:  0.849202468792
# R_squared_0:  0.81531558925
# Slope:  1.00791330745
# Scikit_Explained_variance:  0.791882032988
# Scikit_R2_score:  0.789553797008
# Scikit_MSE:  0.454563798464
#
# 5
# RMSE:  0.4472135955
# Q_squared:  0.916666666667
# R_squared:  0.909121956748
# R_squared_0:  0.931790123457
# Slope:  0.974074074074
# ...

# %%
figure,(plt1,plt2) = pylab.subplots(1,2)
figure.set_size_inches(15,5)
plt1.plot(frame1.X-1,frame1.X,c='red',linewidth=1,zorder=1)
plt1.plot(frame1.X+1,frame1.X,c='red',linewidth=1,zorder=1)
plt1.scatter(frame1.Y,frame1.X,c='green',label='test',zorder=2)
minn = np.min(np.concatenate([frame1.Y,frame1.X],axis=0))
maxx = np.max(np.concatenate([frame1.Y,frame1.X],axis=0))
plt1.set_ylim([minn,maxx])
plt1.set_xlim([minn,maxx])
plt1.set_title("Frame 1")

plt2.plot(frame1.X-1,frame1.X,c='red',linewidth=1,zorder=1)
plt2.plot(frame1.X+1,frame1.X,c='red',linewidth=1,zorder=1)
plt2.scatter(frame2.Y,frame2.X,c='green',label='test',zorder=2)
plt2.set_title("Frame 2")
minn = np.min(np.concatenate([frame2.Y,frame2.X],axis=0))
maxx = np.max(np.concatenate([frame2.Y,frame2.X],axis=0))
plt2.set_ylim([minn,maxx])
plt2.set_xlim([minn,maxx])

figure,(plt3,plt4) = pylab.subplots(1,2)
figure.set_size_inches(15,5)
plt3.plot(frame1.X-1,frame1.X,c='red',linewidth=1,zorder=1)
plt3.plot(frame1.X+1,frame1.X,c='red',linewidth=1,zorder=1)
plt3.scatter(frame3.Y,frame3.X,c='green',label='test',zorder=2)
minn = np.min(np.concatenate([frame3.Y,frame3.X],axis=0))
maxx = np.max(np.concatenate([frame3.Y,frame3.X],axis=0))
plt3.set_ylim([minn,maxx])
plt3.set_xlim([minn,maxx])
plt3.set_title("Frame 3")

plt4.plot(frame1.X-1,frame1.X,c='red',linewidth=1,zorder=1)
plt4.plot(frame1.X+1,frame1.X,c='red',linewidth=1,zorder=1)
plt4.scatter(frame4.Y,frame4.X,c='green',label='test',zorder=2)
plt4.set_title("Frame 4")
minn = np.min(np.concatenate([frame4.Y,frame4.X],axis=0))
maxx = np.max(np.concatenate([frame4.Y,frame4.X],axis=0))
plt4.set_ylim([minn,maxx])
plt4.set_xlim([minn,maxx])


figure,(plt5,plt6) = pylab.subplots(1,2)
figure.set_size_inches(15,5)
plt5.plot(frame1.X-1,frame1.X,c='red',linewidth=1,zorder=1)
plt5.plot(frame1.X+1,frame1.X,c='red',linewidth=1,zorder=1)
plt5.scatter(frame5.Y,frame5.X,c='green',label='test',zorder=2)
minn = np.min(np.concatenate([frame5.Y,frame5.X],axis=0))
maxx = np.max(np.concatenate([frame5.Y,frame5.X],axis=0))
plt5.set_ylim([minn,maxx])
plt5.set_xlim([minn,maxx])
plt5.set_title("Frame 5")
